# %% [markdown]
# # Week 2 Exercises - Interactive
#
# Complete these exercises on syntax, data types, operators, and conditionals.
#
# **Points:** 90 auto-graded, plus up to 10 bonus from the two challenges.
#
# **When finished:**
# 1. Make sure all tests pass (show ✅)
# 2. Run the score cell at the bottom
# 3. Download: `File > Download as > Notebook (.ipynb)`
# 4. Rename to: `LastName_FirstName_Exc2.ipynb`
# 5. Submit to the Canvas assignment **Exercise 2 — Data Types & Operators**
#
# ---

# %% [markdown]
# ## Part 1: Data Type Exploration (15 points)
#
# Create variables and explore their types:
# 1. Create `student_count` = 25 (int)
# 2. Create `average_grade` = 87.5 (float)
# 3. Create `course_code` = "LIS826" (str)
# 4. Create `is_online` = True (bool)
# 5. Use `type()` to verify (code provided below)

# %%
# YOUR CODE HERE
student_count =
average_grade =
course_code =
is_online =

# %%
# TEST CELL
def test_part1():
    try:
        assert student_count == 25 and type(student_count) == int, "student_count should be 25 (int)"
        assert average_grade == 87.5 and type(average_grade) == float, "average_grade should be 87.5 (float)"
        assert course_code == "LIS826" and type(course_code) == str, "course_code should be 'LIS826' (str)"
        assert is_online == True and type(is_online) == bool, "is_online should be True (bool)"
        print("✅ Part 1 PASSED!")
        return True
    except AssertionError as e:
        print(f"❌ {e}")
        return False
    except NameError as e:
        print(f"❌ Not defined yet - {e}")
        return False

test_part1()

# %% [markdown]
# ## Part 2: Mathematical Operations (20 points)
#
# Solve these calculations:
# 1. `total_cost` = 45.99 + 23.50 + 67.25
# 2. `discounted_price` = 99.99 * 0.85 (15% off)
# 3. `remainder` = 17 % 5 (modulus)
# 4. `power` = 2 ** 8 (2 to the 8th power)
# 5. `average` = (85 + 92 + 78 + 90 + 88) / 5

# %%
# YOUR CODE HERE
total_cost = 
discounted_price = 
remainder = 
power = 
average =

# %%
# TEST CELL
def test_part2():
    try:
        assert abs(total_cost - 136.74) < 0.01, "total_cost should be 136.74"
        assert abs(discounted_price - 84.9915) < 0.01, "discounted_price should be about 84.99"
        assert remainder == 2, "remainder should be 2"
        assert power == 256, "power should be 256"
        assert abs(average - 86.6) < 0.1, "average should be 86.6"
        print("✅ Part 2 PASSED!")
        return True
    except AssertionError as e:
        print(f"❌ {e}")
        return False
    except NameError as e:
        print(f"❌ Not defined yet - {e}")
        return False

test_part2()

# %% [markdown]
# ## Part 3: String Manipulation (20 points)
#
# Create and manipulate strings:
# 1. `first` = "Python"
# 2. `second` = "Programming"
# 3. `combined` = first + " " + second (concatenation)
# 4. `repeated` = "Code" * 3 (repetition)
# 5. `greeting` = f"Welcome to {first} {second}!" (f-string)

# %%
# YOUR CODE HERE
first = 
second = 
combined = 
repeated = 
greeting =

# %%
# TEST CELL
def test_part3():
    try:
        assert first == "Python", "first should be 'Python'"
        assert second == "Programming", "second should be 'Programming'"
        assert combined == "Python Programming", "combined should be 'Python Programming'"
        assert repeated == "CodeCodeCode", "repeated should be 'CodeCodeCode'"
        assert greeting == "Welcome to Python Programming!", "greeting should be 'Welcome to Python Programming!'"
        print("✅ Part 3 PASSED!")
        return True
    except AssertionError as e:
        print(f"❌ {e}")
        return False
    except NameError as e:
        print(f"❌ Not defined yet - {e}")
        return False

test_part3()

# %% [markdown]
# ## Part 4: Type Conversion (20 points)
#
# Convert between types:
# 1. `num_str` = "42" → convert to `num_int` (int)
# 2. `price_str` = "19.99" → convert to `price_float` (float)
# 3. `count` = 100 → convert to `count_str` (string)
# 4. `value` = 0 → convert to `value_bool` (boolean using bool())

# %%
# YOUR CODE HERE
num_str = "42"
num_int = 

price_str = "19.99"
price_float = 

count = 100
count_str = 

value = 0
value_bool =

# %%
# TEST CELL
def test_part4():
    try:
        assert num_int == 42 and type(num_int) == int, "num_int should be 42 (int)"
        assert price_float == 19.99 and type(price_float) == float, "price_float should be 19.99 (float)"
        assert count_str == "100" and type(count_str) == str, "count_str should be '100' (str)"
        assert value_bool == False and type(value_bool) == bool, "value_bool should be False (bool)"
        print("✅ Part 4 PASSED!")
        return True
    except AssertionError as e:
        print(f"❌ {e}")
        return False
    except NameError as e:
        print(f"❌ Not defined yet - {e}")
        return False

test_part4()

# %% [markdown]
# ## Part 5: Conditional Logic (15 points)
#
# ### 5a: Grade Check (8 points)
#
# Write a **function** called `grade_for(score)` that uses `if` / `elif` / `else`
# and **returns** one of these strings:
#
# | Score | Returns |
# |---|---|
# | 90 or above | `"Excellent!"` |
# | 80 to 89 | `"Good job!"` |
# | 70 to 79 | `"Passing"` |
# | below 70 | `"Needs improvement"` |
#
# Writing it as a function lets the test cell call it with several different scores
# — including the boundary values 90, 80 and 70 — instead of just one.

# %%
# YOUR CODE HERE
def grade_for(score):
    # Write your if / elif / else statements, and return the right string
    pass


# Try it out
for s in [95, 85, 75, 65]:
    print(f"Score {s}: {grade_for(s)}")

# %%
# TEST CELL
def test_part5a():
    cases = [
        (100, "Excellent!"), (95, "Excellent!"), (90, "Excellent!"),
        (89, "Good job!"), (85, "Good job!"), (80, "Good job!"),
        (79, "Passing"), (75, "Passing"), (70, "Passing"),
        (69, "Needs improvement"), (0, "Needs improvement"),
    ]
    try:
        failures = []
        for score_in, expected in cases:
            actual = grade_for(score_in)
            if actual != expected:
                failures.append(f"grade_for({score_in}) returned {actual!r}, expected {expected!r}")
        if failures:
            print("❌ Part 5a failed on:")
            for f in failures[:4]:
                print(f"   - {f}")
            if len(failures) > 4:
                print(f"   ...and {len(failures) - 4} more")
            print("   (check your boundaries: 90, 80 and 70 belong to the HIGHER band)")
            return False
        print("✅ Part 5a PASSED! Correct for all 11 test scores, boundaries included.")
        return True
    except NameError as e:
        print(f"❌ Not defined yet - {e}")
        return False
    except TypeError as e:
        print(f"❌ grade_for() raised a TypeError - {e}")
        return False

test_part5a()

# %% [markdown]
# ### 5b: Even or Odd (7 points)
#
# Write a **function** called `parity_of(number)` that uses the modulus (`%`)
# operator and **returns** the string `"even"` or `"odd"`.

# %%
# YOUR CODE HERE
def parity_of(number):
    # Use the modulus operator (%) and return "even" or "odd"
    pass


# Try it out
for n in [7, 10, 0, -3]:
    print(f"{n} is {parity_of(n)}")

# %%
# TEST CELL
def test_part5b():
    cases = [(7, "odd"), (10, "even"), (0, "even"), (-3, "odd"), (-4, "even"), (1, "odd")]
    try:
        failures = [f"parity_of({n}) returned {parity_of(n)!r}, expected {want!r}"
                    for n, want in cases if parity_of(n) != want]
        if failures:
            print("❌ Part 5b failed on:")
            for f in failures:
                print(f"   - {f}")
            print("   (remember 0 is even, and negative numbers count too)")
            return False
        print("✅ Part 5b PASSED! Correct for even, odd, zero and negatives.")
        return True
    except NameError as e:
        print(f"❌ Not defined yet - {e}")
        return False
    except TypeError as e:
        print(f"❌ parity_of() raised a TypeError - {e}")
        return False

test_part5b()

# %% [markdown]
# ## Challenge 1: Temperature Converter (5 bonus points)
#
# Create a temperature converter:
# - Start with `celsius = 25`
# - Convert to Fahrenheit: `fahrenheit = celsius * 9/5 + 32`
# - Create message: `temp_message` = "25°C is 77.0°F"

# %%
# YOUR CODE HERE
celsius = 25
fahrenheit = 
temp_message = 

print(temp_message)

# %%
# TEST CELL
def test_challenge1():
    try:
        assert fahrenheit == 77.0, "fahrenheit should be 77.0"
        assert "25" in temp_message and "77" in temp_message, "Message should contain both temperatures"
        print("✅ Challenge 1 PASSED!")
        return True
    except AssertionError as e:
        print(f"❌ {e}")
        return False
    except NameError as e:
        print(f"❌ Not defined yet - {e}")
        return False

test_challenge1()

# %% [markdown]
# ## Challenge 2: Shopping Cart (5 bonus points)
#
# Calculate a shopping cart total:
# - `item1_price` = 29.99
# - `item2_price` = 15.50
# - `item3_price` = 8.25
# - Calculate `subtotal`
# - Calculate `tax` (7% of subtotal)
# - Calculate `total`
# - Create formatted message showing all values

# %%
# YOUR CODE HERE
item1_price = 29.99
item2_price = 15.50
item3_price = 8.25

subtotal = 
tax = 
total = 

print(f"Subtotal: ${subtotal:.2f}")
print(f"Tax: ${tax:.2f}")
print(f"Total: ${total:.2f}")

# %%
# TEST CELL
def test_challenge2():
    try:
        assert abs(subtotal - 53.74) < 0.01, "subtotal should be 53.74"
        assert abs(tax - 3.76) < 0.01, "tax should be about 3.76 (7% of subtotal)"
        assert abs(total - 57.50) < 0.01, "total should be about 57.50"
        print("✅ Challenge 2 PASSED!")
        return True
    except AssertionError as e:
        print(f"❌ {e}")
        return False
    except NameError as e:
        print(f"❌ Not defined yet - {e}")
        return False

test_challenge2()

# %% [markdown]
# ---
#
# ## 📊 Check Your Score

# %%
# Calculate your score
# NOTE: these names are deliberately not `score` or `total` — those belong to
# your answers in Part 5 and Challenge 2, and overwriting them here would make
# the tests grade the wrong thing.
MAX_BASE = 90
MAX_BONUS = 10
earned = 0

print("=" * 50)
print("WEEK 2 EXERCISES - SCORE REPORT")
print("=" * 50)

if test_part1():
    earned += 15
if test_part2():
    earned += 20
if test_part3():
    earned += 20
if test_part4():
    earned += 20
if test_part5a():
    earned += 8
if test_part5b():
    earned += 7

bonus = 0
if test_challenge1():
    bonus += 5
if test_challenge2():
    bonus += 5

print("\n" + "=" * 50)
print(f"BASE SCORE: {earned}/{MAX_BASE} ({earned / MAX_BASE * 100:.1f}%)")
print(f"BONUS: {bonus}/{MAX_BONUS}")
print(f"TOTAL: {earned + bonus}/{MAX_BASE + MAX_BONUS}")
print("=" * 50)

if earned >= 72:    # 80%
    print("\n✅ Excellent! Ready to submit.")
elif earned >= 54:  # 60%
    print("\n⚠️  Good progress! Review the parts that failed.")
else:
    print("\n❌ Keep working! Ask for help if you need it.")

print("\n📥 To submit: File > Download as > Notebook (.ipynb)")
print("Rename to: LastName_FirstName_Exc2.ipynb")

# %% [markdown]
# ---
#
# ## Submission Checklist
#
# - [ ] All parts show ✅ in tests
# - [ ] Score is at least 72/90 (80%)
# - [ ] File renamed: `LastName_FirstName_Exc2.ipynb`
# - [ ] Downloaded as .ipynb file
#
# **Submit to:** Canvas assignment **Exercise 2 — Data Types & Operators**
