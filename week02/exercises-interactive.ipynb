# %% [markdown]
# # Week 2 Exercises - Interactive
#
# Complete these exercises on syntax, data types, operators, and conditionals.
#
# **When finished:**
# 1. Make sure all tests pass (show ✅)
# 2. Download: `File > Download as > Notebook (.ipynb)`
# 3. Rename to: `LastName_FirstName_Week02.ipynb`
# 4. Submit to Canvas
#
# ---

# %% [markdown]
# ## Part 1: Data Type Exploration (15 points)
#
# Create variables and explore their types:
# 1. Create `student_count` = 25 (int)
# 2. Create `average_grade` = 87.5 (float)
# 3. Create `course_code` = "LIS440" (str)
# 4. Create `is_online` = True (bool)
# 5. Use `type()` to verify (code provided below)

# %%
# YOUR CODE HERE
student_count = 
average_grade = 
course_code = 
is_online =

# %%
# TEST CELL
def test_part1():
    try:
        assert student_count == 25 and type(student_count) == int, "student_count should be 25 (int)"
        assert average_grade == 87.5 and type(average_grade) == float, "average_grade should be 87.5 (float)"
        assert course_code == "LIS440" and type(course_code) == str, "course_code should be 'LIS440' (str)"
        assert is_online == True and type(is_online) == bool, "is_online should be True (bool)"
        print("✅ Part 1 PASSED!")
        return True
    except AssertionError as e:
        print(f"❌ {e}")
        return False

test_part1()

# %% [markdown]
# ## Part 2: Mathematical Operations (20 points)
#
# Solve these calculations:
# 1. `total_cost` = 45.99 + 23.50 + 67.25
# 2. `discounted_price` = 99.99 * 0.85 (15% off)
# 3. `remainder` = 17 % 5 (modulus)
# 4. `power` = 2 ** 8 (2 to the 8th power)
# 5. `average` = (85 + 92 + 78 + 90 + 88) / 5

# %%
# YOUR CODE HERE
total_cost = 
discounted_price = 
remainder = 
power = 
average =

# %%
# TEST CELL
def test_part2():
    try:
        assert abs(total_cost - 136.74) < 0.01, "total_cost should be 136.74"
        assert abs(discounted_price - 84.9915) < 0.01, "discounted_price should be about 84.99"
        assert remainder == 2, "remainder should be 2"
        assert power == 256, "power should be 256"
        assert abs(average - 86.6) < 0.1, "average should be 86.6"
        print("✅ Part 2 PASSED!")
        return True
    except AssertionError as e:
        print(f"❌ {e}")
        return False

test_part2()

# %% [markdown]
# ## Part 3: String Manipulation (20 points)
#
# Create and manipulate strings:
# 1. `first` = "Python"
# 2. `second` = "Programming"
# 3. `combined` = first + " " + second (concatenation)
# 4. `repeated` = "Code" * 3 (repetition)
# 5. `greeting` = f"Welcome to {first} {second}!" (f-string)

# %%
# YOUR CODE HERE
first = 
second = 
combined = 
repeated = 
greeting =

# %%
# TEST CELL
def test_part3():
    try:
        assert first == "Python", "first should be 'Python'"
        assert second == "Programming", "second should be 'Programming'"
        assert combined == "Python Programming", "combined should be 'Python Programming'"
        assert repeated == "CodeCodeCode", "repeated should be 'CodeCodeCode'"
        assert greeting == "Welcome to Python Programming!", "greeting should be 'Welcome to Python Programming!'"
        print("✅ Part 3 PASSED!")
        return True
    except AssertionError as e:
        print(f"❌ {e}")
        return False

test_part3()

# %% [markdown]
# ## Part 4: Type Conversion (20 points)
#
# Convert between types:
# 1. `num_str` = "42" → convert to `num_int` (int)
# 2. `price_str` = "19.99" → convert to `price_float` (float)
# 3. `count` = 100 → convert to `count_str` (string)
# 4. `value` = 0 → convert to `value_bool` (boolean using bool())

# %%
# YOUR CODE HERE
num_str = "42"
num_int = 

price_str = "19.99"
price_float = 

count = 100
count_str = 

value = 0
value_bool =

# %%
# TEST CELL
def test_part4():
    try:
        assert num_int == 42 and type(num_int) == int, "num_int should be 42 (int)"
        assert price_float == 19.99 and type(price_float) == float, "price_float should be 19.99 (float)"
        assert count_str == "100" and type(count_str) == str, "count_str should be '100' (str)"
        assert value_bool == False and type(value_bool) == bool, "value_bool should be False (bool)"
        print("✅ Part 4 PASSED!")
        return True
    except AssertionError as e:
        print(f"❌ {e}")
        return False

test_part4()

# %% [markdown]
# ## Part 5: Conditional Logic (15 points)
#
# Write conditional statements:
#
# ### 5a: Grade Check
# Create variable `grade_message` based on `score`:
# - If score >= 90: "Excellent!"
# - If score >= 80: "Good job!"
# - If score >= 70: "Passing"
# - Otherwise: "Needs improvement"

# %%
# Test with different scores
score = 85  # Change this to test different cases

# YOUR CODE HERE - Write if/elif/else statements


print(f"Score {score}: {grade_message}")

# %%
# TEST CELL
def test_part5a():
    global grade_message
    tests_passed = 0
    
    # Test case 1: score 95
    score = 95
    if score >= 90:
        grade_message = "Excellent!"
    elif score >= 80:
        grade_message = "Good job!"
    elif score >= 70:
        grade_message = "Passing"
    else:
        grade_message = "Needs improvement"
    
    # Now test with your code
    test_scores = [(95, "Excellent!"), (85, "Good job!"), (75, "Passing"), (65, "Needs improvement")]
    
    for test_score, expected in test_scores:
        score = test_score
        # Student's code should be in the cell above
        # We'll just verify the logic exists
        pass
    
    print("✅ Part 5a logic checked - verify your if/elif/else works for all cases")
    return True

test_part5a()

# %% [markdown]
# ### 5b: Even or Odd
# Create variable `parity` that says "even" or "odd" based on `number`

# %%
number = 7  # Change this to test

# YOUR CODE HERE - Use modulus (%) operator


print(f"{number} is {parity}")

# %%
# TEST CELL
def test_part5b():
    # Manual verification
    print("✅ Part 5b - verify your code works for even AND odd numbers")
    return True

test_part5b()

# %% [markdown]
# ## Challenge 1: Temperature Converter (5 bonus points)
#
# Create a temperature converter:
# - Start with `celsius = 25`
# - Convert to Fahrenheit: `fahrenheit = celsius * 9/5 + 32`
# - Create message: `temp_message` = "25°C is 77.0°F"

# %%
# YOUR CODE HERE
celsius = 25
fahrenheit = 
temp_message = 

print(temp_message)

# %%
# TEST CELL
def test_challenge1():
    try:
        assert fahrenheit == 77.0, "fahrenheit should be 77.0"
        assert "25" in temp_message and "77" in temp_message, "Message should contain both temperatures"
        print("✅ Challenge 1 PASSED!")
        return True
    except AssertionError as e:
        print(f"❌ {e}")
        return False

test_challenge1()

# %% [markdown]
# ## Challenge 2: Shopping Cart (5 bonus points)
#
# Calculate a shopping cart total:
# - `item1_price` = 29.99
# - `item2_price` = 15.50
# - `item3_price` = 8.25
# - Calculate `subtotal`
# - Calculate `tax` (7% of subtotal)
# - Calculate `total`
# - Create formatted message showing all values

# %%
# YOUR CODE HERE
item1_price = 29.99
item2_price = 15.50
item3_price = 8.25

subtotal = 
tax = 
total = 

print(f"Subtotal: ${subtotal:.2f}")
print(f"Tax: ${tax:.2f}")
print(f"Total: ${total:.2f}")

# %%
# TEST CELL
def test_challenge2():
    try:
        assert abs(subtotal - 53.74) < 0.01, "subtotal should be 53.74"
        assert abs(tax - 3.76) < 0.01, "tax should be about 3.76 (7% of subtotal)"
        assert abs(total - 57.50) < 0.01, "total should be about 57.50"
        print("✅ Challenge 2 PASSED!")
        return True
    except AssertionError as e:
        print(f"❌ {e}")
        return False

test_challenge2()

# %% [markdown]
# ---
#
# ## 📊 Check Your Score

# %%
# Calculate total score
score = 0
total = 90

print("=" * 50)
print("WEEK 2 EXERCISES - SCORE REPORT")
print("=" * 50)

if test_part1():
    score += 15
if test_part2():
    score += 20
if test_part3():
    score += 20
if test_part4():
    score += 20
if test_part5a():
    score += 8
if test_part5b():
    score += 7

# Bonus
bonus = 0
if test_challenge1():
    bonus += 5
if test_challenge2():
    bonus += 5

print("\n" + "=" * 50)
print(f"BASE SCORE: {score}/{total} ({score/total*100:.1f}%)")
print(f"BONUS: {bonus}/10")
print(f"TOTAL: {score + bonus}/100")
print("=" * 50)

if score >= 72:  # 80%
    print("\n✅ Excellent! Ready to submit.")
elif score >= 54:  # 60%
    print("\n⚠️  Good progress! Review failed exercises.")
else:
    print("\n❌ Keep working! Ask for help if needed.")

print("\n📥 To submit: File > Download as > Notebook (.ipynb)")
print("Rename to: LastName_FirstName_Week02.ipynb")

# %% [markdown]
# ---
#
# ## Submission Checklist
#
# - [ ] All parts show ✅ in tests
# - [ ] Score is at least 72/90 (80%)
# - [ ] File renamed: `LastName_FirstName_Week02.ipynb`
# - [ ] Downloaded as .ipynb file
#
# **Submit to:** Canvas Assignment "Week 2 Exercises"
