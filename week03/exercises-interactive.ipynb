# %% [markdown]
# # Week 3 Exercises - Interactive
#
# String methods, user input, and formatting exercises with auto-grading.
#
# **Submit:** `LastName_FirstName_Week03.ipynb` to Canvas
#
# ---

# %% [markdown]
# ## Exercise 1: String Methods (20 points)
#
# Given `text = "  Python Programming  "`, create:
# 1. `clean_text` - remove whitespace with `.strip()`
# 2. `upper_text` - convert to uppercase
# 3. `lower_text` - convert to lowercase
# 4. `title_text` - convert to title case
# 5. `replaced_text` - replace "Python" with "Advanced Python"

# %%
text = "  Python Programming  "

# YOUR CODE HERE
clean_text = 
upper_text = 
lower_text = 
title_text = 
replaced_text =

# %%
# TEST
def test_ex1():
    try:
        assert clean_text == "Python Programming", "clean_text should have no whitespace"
        assert upper_text == "PYTHON PROGRAMMING", "upper_text should be uppercase"
        assert lower_text == "python programming", "lower_text should be lowercase"
        assert title_text == "Python Programming", "title_text should be title case"
        assert "Advanced Python" in replaced_text, "replaced_text should contain 'Advanced Python'"
        print("✅ Exercise 1 PASSED!")
        return 20
    except AssertionError as e:
        print(f"❌ {e}")
        return 0

test_ex1()

# %% [markdown]
# ## Exercise 2: String Formatting (20 points)
#
# Create variables:
# - `name` = "Alice"
# - `age` = 25
# - `gpa` = 3.85
#
# Create `profile` using f-string:
# - "Name: Alice, Age: 25, GPA: 3.85"

# %%
# YOUR CODE HERE
name = "Alice"
age = 25
gpa = 3.85

profile = 

print(profile)

# %%
# TEST
def test_ex2():
    try:
        assert "Alice" in profile and "25" in profile and "3.85" in profile
        print("✅ Exercise 2 PASSED!")
        return 20
    except:
        print("❌ Check your f-string formatting")
        return 0

test_ex2()

# %% [markdown]
# ## Exercise 3: String Slicing (20 points)
#
# Given `word = "Programming"`:
# 1. `first_three` - first 3 characters
# 2. `last_three` - last 3 characters
# 3. `middle` - characters from index 3 to 7
# 4. `every_other` - every other character
# 5. `reversed_word` - word reversed

# %%
word = "Programming"

# YOUR CODE HERE
first_three = 
last_three = 
middle = 
every_other = 
reversed_word =

# %%
# TEST
def test_ex3():
    try:
        assert first_three == "Pro"
        assert last_three == "ing"
        assert middle == "gram"
        assert every_other == "Pormin"
        assert reversed_word == "gnimmargorP"
        print("✅ Exercise 3 PASSED!")
        return 20
    except:
        print("❌ Check your slicing syntax")
        return 0

test_ex3()

# %% [markdown]
# ## Exercise 4: Split and Join (20 points)
#
# Given `sentence = "Python is awesome"`:
# 1. `words_list` - split into list of words
# 2. `word_count` - count of words
# 3. `joined` - join words with "-"
# 4. `initials` - first letter of each word ("Pia")

# %%
sentence = "Python is awesome"

# YOUR CODE HERE
words_list = 
word_count = 
joined = 
initials =

# %%
# TEST
def test_ex4():
    try:
        assert words_list == ["Python", "is", "awesome"]
        assert word_count == 3
        assert joined == "Python-is-awesome"
        assert initials == "Pia"
        print("✅ Exercise 4 PASSED!")
        return 20
    except:
        print("❌ Check split/join methods")
        return 0

test_ex4()

# %% [markdown]
# ## Exercise 5: Email Validator (20 points)
#
# Create function `validate_email(email)` that returns:
# - True if email contains "@" and "."
# - False otherwise

# %%
# YOUR CODE HERE
def validate_email(email):
    # Add your code
    pass

# Test your function
print(validate_email("user@example.com"))  # Should be True
print(validate_email("invalid.email"))      # Should be False

# %%
# TEST
def test_ex5():
    try:
        assert validate_email("test@email.com") == True
        assert validate_email("no-at-sign.com") == False
        assert validate_email("no-dot@email") == False
        print("✅ Exercise 5 PASSED!")
        return 20
    except:
        print("❌ Check your validation logic")
        return 0

test_ex5()

# %% [markdown]
# ## 📊 Final Score

# %%
total = test_ex1() + test_ex2() + test_ex3() + test_ex4() + test_ex5()

print("\n" + "=" * 50)
print(f"TOTAL SCORE: {total}/100")
print("=" * 50)

if total >= 80:
    print("✅ Excellent work!")
else:
    print("Keep practicing!")

print("\n📥 Download as: LastName_FirstName_Week03.ipynb")
