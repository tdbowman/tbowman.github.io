# %% [markdown]
# # Week 1 Exercises - Interactive
#
# Complete these exercises directly in this notebook. Run the test cells to check
# your answers.
#
# **Points:** 85 auto-graded + 15 instructor-reviewed (Exercise 4) = **100**.
# The Challenge at the end is worth up to 10 bonus points on top.
#
# **When finished:**
# 1. Make sure every test cell shows ✅ (Exercise 4 is reviewed by hand)
# 2. Run the score cell at the bottom
# 3. Download this notebook: `File > Download as > Notebook (.ipynb)`
# 4. Rename it to `LastName_FirstName_Exc1.ipynb`
# 5. Submit it to the Canvas assignment **Exercise 1 — Variables & Naming**
#
# ---

# %% [markdown]
# ## Exercise 1: Create Variables (20 points)
#
# Create the following variables with the specified values:
# - `first_name` with your first name (string)
# - `last_name` with your last name (string)
# - `age` with your age (integer)
# - `gpa` with a sample GPA (float, e.g., 3.8)

# %%
# YOUR CODE HERE
first_name = 
last_name = 
age = 
gpa =

# %%
# TEST CELL - Run this to check your answer
def test_exercise_1():
    try:
        assert isinstance(first_name, str) and len(first_name) > 0, "first_name should be a non-empty string"
        assert isinstance(last_name, str) and len(last_name) > 0, "last_name should be a non-empty string"
        assert isinstance(age, int) and not isinstance(age, bool), "age should be an integer (not True/False)"
        assert isinstance(gpa, float), "gpa should be a float, e.g. 3.8 (not 4)"
        print("✅ Exercise 1 PASSED! All variables created correctly.")
        return True
    except AssertionError as e:
        print(f"❌ Error: {e}")
        return False
    except NameError as e:
        print(f"❌ Error: Variable not defined - {e}")
        return False

test_exercise_1()

# %% [markdown]
# ## Exercise 2: Variable Naming (20 points)
#
# Fix the following variable names to follow Python naming conventions:
# - Use snake_case
# - Be descriptive
# - No spaces or special characters
#
# Create variables with corrected names and assign them the given values:
# - `2ndPlace` → should be `second_place = "Silver"`
# - `my-email` → should be `my_email = "student@example.com"`
# - `MAXSCORE` → should be `max_score = 100`

# %%
# YOUR CODE HERE
# Create the three correctly-named variables

# %%
# TEST CELL - Run this to check your answer
def test_exercise_2():
    try:
        assert 'second_place' in globals(), "Create variable 'second_place'"
        assert second_place == "Silver", "second_place should equal 'Silver'"
        assert 'my_email' in globals(), "Create variable 'my_email'"
        assert my_email == "student@example.com", "my_email should equal 'student@example.com'"
        assert 'max_score' in globals(), "Create variable 'max_score'"
        assert max_score == 100, "max_score should equal 100"
        print("✅ Exercise 2 PASSED! All variable names correct.")
        return True
    except AssertionError as e:
        print(f"❌ Error: {e}")
        return False
    except NameError as e:
        print(f"❌ Error: {e}")
        return False

test_exercise_2()

# %% [markdown]
# ## Exercise 3: Print Statements (25 points)
#
# Using the variables from Exercise 1, create a formatted message:
# - Store the message in a variable called `intro_message`
# - The message should say: "My name is [first_name] [last_name], I am [age] years old, and my GPA is [gpa]."
# - Use string concatenation or f-strings

# %%
# YOUR CODE HERE
intro_message = 

# Print your message to see it
print(intro_message)

# %%
# TEST CELL - Run this to check your answer
def test_exercise_3():
    try:
        assert 'intro_message' in globals(), "Create variable 'intro_message'"
        assert isinstance(intro_message, str), "intro_message should be a string"
        assert first_name in intro_message, "Message should include your first_name"
        assert last_name in intro_message, "Message should include your last_name"
        assert str(age) in intro_message, "Message should include your age"
        assert str(gpa) in intro_message, "Message should include your gpa"
        print("✅ Exercise 3 PASSED! Message formatted correctly.")
        print(f"Your message: {intro_message}")
        return True
    except AssertionError as e:
        print(f"❌ Error: {e}")
        return False
    except NameError as e:
        print(f"❌ Error: {e}")
        return False

test_exercise_3()

# %% [markdown]
# ## Exercise 4: Comments (15 points — reviewed by your instructor)
#
# Add appropriate comments to the following code:
# - Add a comment before the code explaining what it does
# - Add inline comments for complex lines
# - Comments should be meaningful, not just restating the code
#
# There is no automated test for this one. These 15 points are awarded when your
# instructor reads your comments, so the score cell at the bottom will not include
# them.

# %%
# YOUR COMMENTS HERE

radius = 5
pi = 3.14159
area = pi * radius ** 2
circumference = 2 * pi * radius

print(f"Circle with radius {radius}:")
print(f"Area: {area}")
print(f"Circumference: {circumference}")

# %%
# No automated test for comments — your instructor reviews these 15 points by hand.
# Before you submit, check that you added:
#   1. A comment explaining what the code does overall
#   2. Comments explaining the calculations
#   3. Meaningful comments (not just "this sets radius to 5")

print("Exercise 4 (Comments): submitted for instructor review — 15 points, not auto-scored")

# %% [markdown]
# ## Exercise 5: Practice with type() (20 points)
#
# Create variables and check their types:
# 1. Create `student_id` with value 12345
# 2. Create `price` with value 19.99
# 3. Create `is_enrolled` with value True
# 4. Create `course_name` with value "Python Programming"
# 5. Use type() to verify each one's type

# %%
# YOUR CODE HERE
student_id = 
price = 
is_enrolled = 
course_name = 

# Check types (leave this code)
print(f"student_id type: {type(student_id)}")
print(f"price type: {type(price)}")
print(f"is_enrolled type: {type(is_enrolled)}")
print(f"course_name type: {type(course_name)}")

# %%
# TEST CELL - Run this to check your answer
def test_exercise_5():
    try:
        assert student_id == 12345, "student_id should be 12345"
        assert isinstance(student_id, int), "student_id should be an integer"
        assert price == 19.99, "price should be 19.99"
        assert isinstance(price, float), "price should be a float"
        assert is_enrolled == True, "is_enrolled should be True"
        assert isinstance(is_enrolled, bool), "is_enrolled should be a boolean"
        assert course_name == "Python Programming", "course_name should be 'Python Programming'"
        assert isinstance(course_name, str), "course_name should be a string"
        print("✅ Exercise 5 PASSED! All types correct.")
        return True
    except AssertionError as e:
        print(f"❌ Error: {e}")
        return False
    except NameError as e:
        print(f"❌ Error: {e}")
        return False

test_exercise_5()

# %% [markdown]
# ## Challenge Exercise (10 bonus points)
#
# Create a simple "Mad Libs" program:
# 1. Create variables for: noun, verb, adjective, place
# 2. Combine them into a silly sentence
# 3. Store in variable `mad_lib_story`
# 4. Print the result
#
# Example: "The [adjective] [noun] decided to [verb] at the [place]."

# %%
# YOUR CODE HERE
noun = 
verb = 
adjective = 
place = 

mad_lib_story = 

print(mad_lib_story)

# %%
# TEST CELL - Run this to check your answer
def test_challenge():
    try:
        assert 'noun' in globals() and isinstance(noun, str), "Create noun variable"
        assert 'verb' in globals() and isinstance(verb, str), "Create verb variable"
        assert 'adjective' in globals() and isinstance(adjective, str), "Create adjective variable"
        assert 'place' in globals() and isinstance(place, str), "Create place variable"
        assert 'mad_lib_story' in globals() and isinstance(mad_lib_story, str), "Create mad_lib_story"
        assert noun in mad_lib_story, "Story should include noun"
        assert verb in mad_lib_story, "Story should include verb"
        assert adjective in mad_lib_story, "Story should include adjective"
        assert place in mad_lib_story, "Story should include place"
        print("✅ BONUS Challenge PASSED!")
        print(f"Your story: {mad_lib_story}")
        return True
    except AssertionError as e:
        print(f"❌ Error: {e}")
        return False
    except NameError as e:
        print(f"❌ Error: {e}")
        return False

test_challenge()

# %% [markdown]
# ---
#
# ## 📊 Check Your Score
#
# Run this cell to see your total score:

# %%
# Run all tests and calculate your score
MAX_AUTO = 85       # Exercises 1, 2, 3 and 5
MANUAL_POINTS = 15  # Exercise 4 (comments), reviewed by your instructor
MAX_BASE = MAX_AUTO + MANUAL_POINTS   # 100
MAX_BONUS = 10

earned = 0

print("=" * 50)
print("WEEK 1 EXERCISES - SCORE REPORT")
print("=" * 50)

if test_exercise_1():
    earned += 20
if test_exercise_2():
    earned += 20
if test_exercise_3():
    earned += 25
print("Exercise 4 (Comments): 15 points, instructor review required")
if test_exercise_5():
    earned += 20

bonus = 10 if test_challenge() else 0

print("\n" + "=" * 50)
print(f"AUTO-GRADED:  {earned}/{MAX_AUTO} ({earned / MAX_AUTO * 100:.1f}%)")
print(f"COMMENTS:     up to {MANUAL_POINTS} more, awarded by your instructor")
print(f"BONUS:        {bonus}/{MAX_BONUS}")
print("-" * 50)
print(f"BEST CASE:    {earned + MANUAL_POINTS}/{MAX_BASE}, plus {bonus} bonus")
print("              (assumes full credit for the Exercise 4 comments)")
print("=" * 50)

if earned >= 68:      # 80% of the auto-graded points
    print("\n✅ Great work! Ready to submit.")
elif earned >= 51:    # 60%
    print("\n⚠️  Good progress! Review the exercises that failed.")
else:
    print("\n❌ Keep working! Ask for help if you need it.")

print("\n📥 To submit: File > Download as > Notebook (.ipynb)")
print("Rename to: LastName_FirstName_Exc1.ipynb")

# %% [markdown]
# ---
#
# ## Submission Checklist
#
# Before submitting, make sure:
# - [ ] All test cells show ✅ (Exercise 4 has no test — it is reviewed by hand)
# - [ ] You've added meaningful comments in Exercise 4
# - [ ] You've run the score check cell
# - [ ] Your auto-graded score is at least 68/85 (80%)
# - [ ] File is named: `LastName_FirstName_Exc1.ipynb`
#
# **To download:** File > Download as > Notebook (.ipynb)
#
# **Submit to:** Canvas assignment **Exercise 1 — Variables & Naming**
